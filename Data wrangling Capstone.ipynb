# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests
import json
import csv
from requests import post
import numpy as np

# %%
Post="https://id.twitch.tv/oauth2/token?client_id=e3t0n1jgss6e7boeecpxk0unupl63e&client_secret=ighphpn6vbvcw4dhoxtpaq2b0p07dj&grant_type=client_credentials"

# %%
print(Post)
# Out:
# https://id.twitch.tv/oauth2/token?client_id=e3t0n1jgss6e7boeecpxk0unupl63e&client_secret=ighphpn6vbvcw4dhoxtpaq2b0p07dj&grant_type=client_credentials

# %%
raw_data = requests.post(Post)

# %%
print(raw_data)
# Out:
# <Response [200]>

# %%
raw_data.json()
# Out:
# {'access_token': 'fmqsxxmgckpaecm0tfliyljcbfrer7',
#  'expires_in': 5456312,
#  'token_type': 'bearer'}

# %%
from requests import post
response = post('https://api.igdb.com/v4/games', **{'headers': {'Client-ID': 'e3t0n1jgss6e7boeecpxk0unupl63e', 'Authorization': 'Bearer pqsi9kzalp46pcofig0rm64t38j6wm'},'data': 'fields aggregated_rating,aggregated_rating_count,alternative_names,category,checksum,genres,involved_companies,name,parent_game,platforms,rating,rating_count,similar_games,themes,total_rating,total_rating_count; limit 500;'})
print ("response: %s" % str(response.json()))
# Out:
# response: [{'id': 176032, 'category': 0, 'genres': [4, 12, 16, 31], 'involved_companies': [153011], 'name': 'Nick Quest', 'platforms': [6], 'similar_games': [13196, 37382, 55199, 81249, 96217, 101608, 103303, 106987, 112191, 115653], 'themes': [17], 'checksum': '56ca73b8-3a8b-80cc-92f0-cc7b1ea66766'}, {'id': 50975, 'category': 0, 'name': 'Storybook Workshop', 'platforms': [5], 'similar_games': [65885, 68787, 71546, 71608, 71964, 73098, 77048, 77122, 78720, 79308], 'checksum': '8459c6cf-99bc-ad81-5f4f-d6cf9a9d17c1'}, {'id': 110814, 'alternative_names': [36514, 36515, 36516, 103360], 'category': 3, 'genres': [5, 8], 'involved_companies': [102218, 102219], 'name': 'Mega Man 30th Anniversary Bundle', 'platforms': [48, 49], 'similar_games': [28070, 55038, 55042, 57187, 68286, 68287, 103292, 105269, 107318, 113362], 'themes': [1, 18], 'checksum': '88b54c59-5523-ebd5-3390-29fc77ba8802'}, {'id': 85450, 'category': 0, 'involved_companies': [85230], 'name': 'Transformers Prime: The Game', 'che
# ...

# %%
game_data_headers= ['name', 'category']

# %%
names = []
category = []
rating = []
total_rating_count = []
genres= []
themes = []
for games in response.json():
    for key, value in games.items():
        if key == 'name':
            names.append(value)
        elif key == 'category':
            category.append(value)
        elif key == 'rating':
            rating.append(value)
        elif key == 'total_rating_count':
            total_rating_count.append(value)
        elif key == 'genres':
            genres.append(value)
        elif key == 'themes':
            themes.append(value)

# %%
print(len(names))
print(len(category))
print(len(rating))
print(len(total_rating_count))
print(len(genres))
print(len(themes))
# Out:
# 500
# 500
# 43
# 52
# 286
# 186

# %%
from requests import post
response = post('https://api.igdb.com/v4/themes', **{'headers': {'Client-ID': 'e3t0n1jgss6e7boeecpxk0unupl63e', 'Authorization': 'Bearer pqsi9kzalp46pcofig0rm64t38j6wm'},'data': 'fields name;'})
print ("response: %s" % str(response.json()))
# Out:
# response: [{'id': 20, 'name': 'Thriller'}, {'id': 18, 'name': 'Science fiction'}, {'id': 1, 'name': 'Action'}, {'id': 19, 'name': 'Horror'}, {'id': 21, 'name': 'Survival'}, {'id': 17, 'name': 'Fantasy'}, {'id': 22, 'name': 'Historical'}, {'id': 23, 'name': 'Stealth'}, {'id': 27, 'name': 'Comedy'}, {'id': 28, 'name': 'Business'}]

# %%
print(themes)
# Out:
# [[17], [1, 18], [34], [1], [17, 22, 27], [1], [1], [1, 21, 27], [1], [38], [19], [18], [1, 18, 33], [1], [1], [1, 39], [1], [1], [27, 44], [42], [1], [18], [1], [17, 27, 43], [19, 20], [1], [1], [1, 17], [1], [1], [17], [42], [1], [1, 31, 43], [1, 18], [19], [1], [19], [1], [1], [17, 27], [40], [1], [1, 18], [17], [1, 18], [1, 17], [1, 18, 21, 23], [34], [1], [1], [1], [17, 27], [19, 43], [1, 18], [1], [34], [19], [1], [1], [1, 17], [1, 17, 18], [1], [1, 17, 21], [42], [1], [1, 17], [1], [31, 44], [27], [1], [18], [19], [1, 39], [22], [40], [19, 23], [1], [1], [1], [1, 27], [27], [1, 27], [1, 18, 27], [18], [1], [17], [1], [18], [1], [1, 21], [19], [27, 44], [1, 41], [1], [1, 19], [1], [1], [1], [19], [19], [40], [1, 17], [1], [44], [1], [19], [19], [1, 27], [42], [19], [17], [42], [1], [1], [17, 44], [17], [1, 39], [1], [1], [17, 27], [1, 17], [1], [18], [1, 21, 38], [1], [17], [1], [1], [1], [35], [17], [1, 21], [1, 27], [1], [1], [17], [1], [1, 17, 18, 22, 23, 27, 28, 35, 38, 39],
# ...

# %%
genres_array= np.array([genres], dtype = object)

# %%
theme_array=np.array([themes], dtype = object)

# %%
print(themes.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20288\17093196.py in <module>
# ----> 1 print(themes.keys())
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
genres_themes_array= [x if x in theme_array else "Null" for x in genres_array]
# Out:
# C:\Users\valdi\AppData\Local\Temp\ipykernel_20288\3206876849.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   genres_themes_array= [x if x in theme_array else "Null" for x in genres_array]

# %%
names_and_category_data = pd.DataFrame({'name': names, 'category':category,})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20288\2423254378.py in <module>
# ----> 1 names_and_category_data = pd.DataFrame({'name': names, 'category':category, 'rating': rating})
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %% [markdown]
# game_data.to_csv('usable_data.csv',index = False)

# %%
names_and_category_data.to_csv('names_and_category.csv',index = False)
